# %% [markdown]
# ![Harshal%20Assignment%20no%202_1.jpg](attachment:Harshal%20Assignment%20no%202_1.jpg)

# %% [markdown]
# ![Harshal%20Assignment%20no%202_2.jpg](attachment:Harshal%20Assignment%20no%202_2.jpg)

# %% [markdown]
# ![Harshal%20Assignment%20no%202_3.jpg](attachment:Harshal%20Assignment%20no%202_3.jpg)
